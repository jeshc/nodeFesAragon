# %% [markdown]
# # Programa del aaron

# %%
nombre = "El Aaron"

# %% [markdown]
# ** A continuaciòn se imprime la variable nombre **
#
# ´´´
# # de la forma
# print(f"El nombre es: {nombre}")
# ´´´
